# %% [markdown]
# # Import needed libraries

# %%
# import system libs 
import os
import time
import shutil
import itertools

# import data handling tools 
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt

# import Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras import regularizers
from tensorflow.keras.metrics import categorical_crossentropy

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %% [markdown]
# ### Read data

# %%
data_dir = '/kaggle/input/skin-cancer-mnist-ham10000/hmnist_28_28_RGB.csv'
data = pd.read_csv(data_dir)
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# ### Split data and labels

# %%
Label = data["label"]
Data = data.drop(columns=["label"])

# %% [markdown]
# ### Handling imbalanced datasets

# %%
from imblearn.over_sampling import RandomOverSampler 

oversample = RandomOverSampler()
Data, Label  = oversample.fit_resample(Data, Label)
Data = np.array(Data).reshape(-1, 28, 28, 3)
print('Shape of Data :', Data.shape)
# Out:
# Shape of Data : (46935, 28, 28, 3)

# %%
Label = np.array(Label)
Label
# Out:
# array([2, 2, 2, ..., 6, 6, 6])

# %% [markdown]
# ### Convert abbreviations to it's words

# %%
classes = {4: ('nv', ' melanocytic nevi'),
           6: ('mel', 'melanoma'),
           2 :('bkl', 'benign keratosis-like lesions'), 
           1:('bcc' , ' basal cell carcinoma'),
           5: ('vasc', ' pyogenic granulomas and hemorrhage'),
           0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
           3: ('df', 'dermatofibroma')}

# %% [markdown]
# ### Splitting train and test

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(Data , Label , test_size = 0.25 , random_state = 49)

# %%
print(f'X_train shape: {X_train.shape}\nX_test shape: {X_test.shape}')
print(f'y_train shape: {y_train.shape}\ny_test shape: {y_test.shape}')
# Out:
# X_train shape: (35201, 28, 28, 3)
# X_test shape: (11734, 28, 28, 3)
# y_train shape: (35201,)
# y_test shape: (11734,)

# %% [markdown]
# ### Convert labels to categorical types

# %%
from keras.utils.np_utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# ### Create Image Data Generation

# %%
datagen = ImageDataGenerator(rescale=(1./255)
                             ,rotation_range=10
                             ,zoom_range = 0.1
                             ,width_shift_range=0.1
                             ,height_shift_range=0.1)

testgen = ImageDataGenerator(rescale=(1./255))

# %% [markdown]
# ### Create ReduceLROnPlateau to learning rate reduction

# %%
from keras.callbacks import ReduceLROnPlateau

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy'
                                            , patience = 2
                                            , verbose=1
                                            ,factor=0.5
                                            , min_lr=0.00001)

# %% [markdown]
# # Model Structure

# %%
model = keras.models.Sequential()

# Create Model Structure
model.add(keras.layers.Input(shape=[28, 28, 3]))
model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal'))
model.add(keras.layers.MaxPooling2D())
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal'))
model.add(keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal'))
model.add(keras.layers.MaxPooling2D())
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal'))
model.add(keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal'))
model.add(keras.layers.MaxPooling2D())
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal'))
model.add(keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal'))
model.add(keras.layers.MaxPooling2D())

model.add(keras.layers.Flatten())

model.add(keras.layers.Dropout(rate=0.2))
model.add(keras.layers.Dense(units=256, activation='relu', kernel_initializer='he_normal'))
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Dense(units=128, activation='relu', kernel_initializer='he_normal'))
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Dense(units=64, activation='relu', kernel_initializer='he_normal'))
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Dense(units=32, activation='relu', kernel_initializer='he_normal', kernel_regularizer=keras.regularizers.L1L2()))
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Dense(units=7, activation='softmax', kernel_initializer='glorot_uniform', name='classifier'))

model.compile(Adamax(learning_rate= 0.001), loss= 'categorical_crossentropy', metrics= ['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 28, 28, 32)        896
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 14, 14, 32)        128
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 14, 14, 64)        18496
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 14, 14, 64)        36928
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 7, 7, 64)          256
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 7, 7, 128)         73856
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 7, 7, 128)         147584
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 3, 3, 128)         0
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 3, 3, 128)         512
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 3, 3, 256)         295168
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 3, 3, 256)         590080
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               65792
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 256)               1024
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 128)               512
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 64)                256
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                2080
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 32)                128
# _________________________________________________________________
# classifier (Dense)           (None, 7)                 231
# =================================================================
# Total params: 1,275,079
# Trainable params: 1,273,671
# Non-trainable params: 1,408
# _________________________________________________________________

# %% [markdown]
# ### Training model

# %%
history = model.fit(X_train ,
                    y_train ,
                    epochs=25 ,
                    batch_size=128,
                    validation_data=(X_test , y_test) ,
                    callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/25
# 276/276 [==============================] - 6s 15ms/step - loss: 1.1437 - accuracy: 0.5915 - val_loss: 0.7870 - val_accuracy: 0.7192
# Epoch 2/25
# 276/276 [==============================] - 3s 12ms/step - loss: 0.4874 - accuracy: 0.8374 - val_loss: 0.3570 - val_accuracy: 0.8783
# Epoch 3/25
# 276/276 [==============================] - 3s 12ms/step - loss: 0.2905 - accuracy: 0.9032 - val_loss: 0.3363 - val_accuracy: 0.8818
# Epoch 4/25
# 276/276 [==============================] - 3s 12ms/step - loss: 0.2084 - accuracy: 0.9280 - val_loss: 0.1777 - val_accuracy: 0.9399
# Epoch 5/25
# 276/276 [==============================] - 4s 13ms/step - loss: 0.1592 - accuracy: 0.9453 - val_loss: 0.1766 - val_accuracy: 0.9437
# Epoch 6/25
# 276/276 [==============================] - 3s 12ms/step - loss: 0.1076 - accuracy: 0.9638 - val_loss: 0.2369 - val_accuracy: 0.9176
# Epoch 7/25
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0862 - accuracy: 0.9723 - val_loss: 0.1513 - val_accuracy: 0.9482
# Epoch 8/25
# 276/276 [==============================] - 3s 13ms/step - loss: 0.0710 - accuracy: 0.9762 - val_loss: 0.1232 - val_accuracy: 0.9607
# Epoch 9/25
# 276/276 [==============================] - 4s 13ms/step - loss: 0.0625 - accuracy: 0.9785 - val_loss: 0.1059 - val_accuracy: 0.9682
# Epoch 10/25
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0469 - accuracy: 0.9839 - val_loss: 0.1155 - val_accuracy: 0.9679
# Epoch 11/25
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0439 - accuracy: 0.9852 - val_loss: 0.1077 - val_accuracy: 0.9691
# Epoch 12/25
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0351 - accuracy: 0.9878 - val_loss: 0.0852 - val_accuracy: 0.9749
# Epoch 13/25
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0342 - accuracy: 0.9888 - val_loss: 0.0917 - val_accuracy: 0.9742
# Epoch 14/25
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0288 - accuracy: 0.9905 - val_loss: 0.0786 - val_accuracy: 0.9782
# Epoch 15/25
# 276/276 [==============================] - 4s 14ms/step - loss: 0.0281 - accuracy: 0.9901 - val_loss: 0.1064 - val_accuracy: 0.9720
# Epoch 16/25
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0290 - accuracy: 0.9893 - val_loss: 0.0775 - val_accuracy: 0.9807
# Epoch 17/25
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0160 - accuracy: 0.9946 - val_loss: 0.1141 - val_accuracy: 0.9714
# Epoch 18/25
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0199 - accuracy: 0.9936 - val_loss: 0.1056 - val_accuracy: 0.9761
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 19/25
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0083 - accuracy: 0.9976 - val_loss: 0.0517 - val_accuracy: 0.9885
# Epoch 20/25
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.0576 - val_accuracy: 0.9881
# Epoch 21/25
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.0552 - val_accuracy: 0.9888
# Epoch 22/25
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0711 - val_accuracy: 0.9852
# Epoch 23/25
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.0676 - val_accuracy: 0.9863
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 24/25
# 276/276 [==============================] - 4s 14ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0651 - val_accuracy: 0.9864
# Epoch 25/25
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0624 - val_accuracy: 0.9876
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.

# %% [markdown]
# ### Show training history

# %%
def plot_training(hist):
    tr_acc = hist.history['accuracy']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_accuracy']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]

    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'
    
    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout
    plt.show()

# %%
plot_training(history)

# %% [markdown]
# # Model Evaluation

# %%
train_score = model.evaluate(X_train, y_train, verbose= 1)
test_score = model.evaluate(X_test, y_test, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 1101/1101 [==============================] - 4s 4ms/step - loss: 8.4595e-05 - accuracy: 1.0000
# 367/367 [==============================] - 2s 4ms/step - loss: 0.0624 - accuracy: 0.9876
# Train Loss:  8.459491073153913e-05
# Train Accuracy:  1.0
# --------------------
# Test Loss:  0.06236174330115318
# Test Accuracy:  0.987642765045166

# %%
y_true = np.array(y_test)
y_pred = model.predict(X_test)

y_pred = np.argmax(y_pred , axis=1)
y_true = np.argmax(y_true , axis=1)

# %% [markdown]
# ### Create classes labels

# %%
classes_labels = []
for key in classes.keys():
    classes_labels.append(key)

print(classes_labels)
# Out:
# [4, 6, 2, 1, 5, 0, 3]

# %% [markdown]
# ### Confussion Matrix

# %%
# Confusion matrix
cm = cm = confusion_matrix(y_true, y_pred, labels=classes_labels)

plt.figure(figsize= (10, 10))
plt.imshow(cm, interpolation= 'nearest', cmap= plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation= 45)
plt.yticks(tick_marks, classes)


thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

plt.show()

# %% [markdown]
# ### Save model

# %%
#Save the model
model.save('Skin Cancer.h5')

# %% [markdown]
# ### Convert model to tflite

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model) 
tflite_model = converter.convert() 

print("model converted")

# Save the model. 
with open('Skin.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# model converted
